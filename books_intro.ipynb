# %% [markdown]
# # Setting Everything Up

# %%
import pandas as pd
from datetime import datetime

# %%
#import the file from the web
import requests
from bs4 import BeautifulSoup
import pandas as pd
from unicodedata import normalize
import re
from datetime import datetime
from pandas import read_csv 
from sklearn.feature_extraction.text import CountVectorizer

# I can give a number or use None to remove maximum ceiling & display all columns
pd.options.display.max_columns = None

# # I want to be able to see the entire narrative, so remove the maximum width for each column
# pd.options.display.max_colwidth = None

pd.options.display.float_format = '{:,.0f}'.format

import string

# %matplotlib inline

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (8, 8)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %%R
#
# # My commonly used R imports
#
# require('tidyverse')
# Out:
# R[write to console]: Loading required package: tidyverse
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.0      ✔ purrr   1.0.1
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.3.0      ✔ stringr 1.5.0
# ✔ readr   2.1.3      ✔ forcats 1.0.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
#To Download PDFs
from urllib.parse import urljoin

# %%
#To import camelot and PDF-related items
import camelot
import ghostscript
import sys

# %%
# %%R
#
# library(jpeg)
# library(wordcloud)
# library(RColorBrewer)
# library(wordcloud2)
# library(tm)
# Out:
# R[write to console]: Loading required package: RColorBrewer
#
# R[write to console]: Loading required package: NLP
#
# R[write to console]:
# Attaching package: ‘NLP’
#
#
# R[write to console]: The following object is masked from ‘package:ggplot2’:
#
#     annotate

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# %%R
# library(vistime)
# library(shiny)
# library(plotly)
# #for timeline plotting
# Out:
# R[write to console]:
# Attaching package: ‘plotly’
#
#
# R[write to console]: The following object is masked from ‘package:ggplot2’:
#
#     last_plot
#
#
# R[write to console]: The following object is masked from ‘package:stats’:
#
#     filter
#
#
# R[write to console]: The following object is masked from ‘package:graphics’:
#
#     layout

# %% [markdown]
# # Books 311 Dataset
#
# #### This is not very helpful but just wanted to add it as background information
# #### Perhaps a more accurate iteration will be pulling books_311 df from 311 data json below so though static it can always be recent
#
# Source: https://data.cityofnewyork.us/Social-Services/311-Service-Requests-from-2010-to-Present/erm2-nwe9/data
#
# Filter for descriptor contains books

# %%
df_books_311 = pd.read_excel('books_311.xlsx')

# %%
df_books_311
# Out:
#       Unique Key        Created Date         Closed Date Agency  \
# 0       37493222 2017-10-22 20:56:11 2019-02-01 14:54:34    TLC
# 1       39506488 2018-06-19 23:05:38 2018-06-20 08:38:46    TLC
# 2       41041472 2018-11-26 23:23:00 2019-02-01 13:45:05    TLC
# 3       42942282 2019-06-11 15:21:39 2019-06-11 15:34:58    TLC
# 4       43068684 2019-06-23 13:34:16 2019-06-24 08:38:25    TLC
# ...          ...                 ...                 ...    ...
# 3296    33785450 2016-07-07 05:52:57 2019-02-01 13:44:52    TLC
# 3297    34084907 2016-08-14 12:36:11 2019-02-01 14:14:16    TLC
# 3298    34101526 2016-08-16 23:34:26 2019-02-01 14:54:46    TLC
# 3299    35014695 2016-12-14 15:10:41 2019-01-31 16:17:46    TLC
# 3300    37289898 2017-09-27 22:39:15 2019-02-01 15:35:32    TLC
#
#                         Agency Name  Complaint Type       Descriptor  \
# 0     Taxi and Limousine Commission  Found Property  Book/Stationery
# 1     Taxi and Limousine Commission  Found Property  Book/Stationery
# 2     Taxi and Limousine Commission  Found Property  Book/Stationery
# 3     Taxi and Limousine Commission   Lost Property  Book/Stationery
# 4     Taxi and Limousine Commission   Lost Property  Book/Stationery
# ...                             ...             ...              ...
# 3296  Taxi and Limousine Commission  Found Property  Book/Stationery
# 3297  Taxi and Limousine Commission  Found Property  Book/Stationery
# 3298  Taxi and Limousine Commission  Found Property  Book/Stationery
# 3299  Taxi and Limousine Commission  Found Property  Book/Stationery
# 3300  Taxi and Limousine Commission  Found Property  Book/Stationery
#
#      Location Type  Incident Zip         Incident Address  \
# 0             Taxi        11,211  875 METROPOLITAN AVENUE
# 1             Taxi        11,217                      NaN
# 2              NaN        10,017             888 2 AVENUE
# 3             Taxi        10,121                      NaN
# 4              NaN        10,003       5 UNIVERSITY PLACE
# ...            ...           ...                      ...
# 3296           NaN        11,105          21-78 35 STREET
# 3297           NaN        10,281         250 VESEY STREET
# 3298          Taxi        10,011                      NaN
# 3299           NaN        10,003           1 FIFTH AVENUE
# 3300          Taxi        10,012                      NaN
#
#               Street Name           Cross Street 1     Cross Street 2  \
# 0     METROPOLITAN AVENUE            ORIENT AVENUE       OLIVE STREET
# 1                     NaN          FLATBUSH AVENUE    FT GREENE PLACE
# 2                2 AVENUE           EAST 47 STREET     EAST 48 STREET
# 3                     NaN           WEST 32 STREET     WEST 33 STREET
# 4        UNIVERSITY PLACE  WASHINGTON SQUARE NORTH    WASHINGTON MEWS
# ...                   ...                      ...                ...
# 3296            35 STREET                21 AVENUE  DITMARS BOULEVARD
# 3297         VESEY STREET            NORTH END WAY   NORTH END AVENUE
# 3298                  NaN                      NaN                NaN
# 3299         FIFTH AVENUE          WASHINGTON MEWS      EAST 8 STREET
# 3300                  NaN                      NaN                NaN
#
#         Intersection Street 1 Intersection Street 2  Address Type      City  \
# 0                         NaN                   NaN       ADDRESS  BROOKLYN
# 1                         NaN                   NaN     PLACENAME  BROOKLYN
# 2                         NaN                   NaN       ADDRESS  NEW YORK
# 3              WEST 32 STREET        WEST 33 STREET     PLACENAME  NEW YORK
# 4     WASHINGTON SQUARE NORTH       WASHINGTON MEWS       ADDRESS  NEW YORK
# ...                       ...                   ...           ...       ...
# 3296                      NaN                   NaN       ADDRESS   ASTORIA
# 3297                      NaN                   NaN       ADDRESS  NEW YORK
# 3298         WEST   15 STREET              6 AVENUE  INTERSECTION  NEW YORK
# 3299                      NaN                   NaN       ADDRESS  NEW YORK
# 3300         EAST    4 STREET              BROADWAY  INTERSECTION  NEW YORK
#
#                   Landmark  Facility Type  Status            Due Date  \
# 0                      NaN            NaN  Closed                 NaT
# 1          BARCLAYS CENTER            NaN  Closed                 NaT
# 2                      NaN            NaN  Closed                 NaT
# 3     PENNSYLVANIA STATION            NaN  Closed                 NaT
# 4                      NaN            NaN  Closed 2019-06-30 13:34:16
# ...                    ...            ...     ...                 ...
# 3296                   NaN            NaN  Closed                 NaT
# 3297                   NaN            NaN  Closed                 NaT
# 3298                   NaN            NaN  Closed                 NaT
# 3299                   NaN            NaN  Closed                 NaT
# 3300                   NaN            NaN  Closed                 NaT
#
#                                  Resolution Description  \
# 0                            See notes for information.
# 1     The Taxi and Limousine Commission will keep a ...
# 2                            See notes for information.
# 3                            See notes for information.
# 4                            See notes for information.
# ...                                                 ...
# 3296                         See notes for information.
# 3297                         See notes for information.
# 3298                         See notes for information.
# 3299                         See notes for information.
# 3300                         See notes for information.
#
#      Resolution Action Updated Date Community Board           BBL    Borough  \
# 0               2019-02-01 14:54:34     01 BROOKLYN 3,029,120,036   BROOKLYN
# 1                               NaT     02 BROOKLYN 3,011,180,001   BROOKLYN
# 2               2019-02-01 13:45:05    06 MANHATTAN 1,013,400,001  MANHATTAN
# 3               2019-06-11 19:34:58    05 MANHATTAN 1,007,810,002  MANHATTAN
# 4               2019-06-24 12:38:25    02 MANHATTAN 1,005,480,004  MANHATTAN
# ...                             ...             ...           ...        ...
# 3296            2019-02-01 13:44:52       01 QUEENS 4,008,307,501     QUEENS
# 3297            2019-02-01 14:14:16    01 MANHATTAN 1,000,160,150  MANHATTAN
# 3298            2019-02-01 14:54:46    04 MANHATTAN           NaN  MANHATTAN
# 3299            2019-01-31 16:17:46    02 MANHATTAN 1,005,500,022  MANHATTAN
# 3300            2019-02-01 15:35:32    02 MANHATTAN           NaN  MANHATTAN
#
#       X Coordinate (State Plane)  Y Coordinate (State Plane)  \
# 0                      1,000,853                     199,654
# 1                        991,034                     188,046
# 2                        992,636                     213,689
# 3                        986,437                     212,546
# 4                        985,535                     205,572
# ...                          ...                         ...
# 3296                   1,009,659                     221,791
# 3297                     979,904                     199,599
# 3298                     985,265                     208,166
# 3299                     985,196                     205,932
# 3300                     985,843                     204,657
#
#      Open Data Channel Type Park Facility Name Park Borough  Vehicle Type  \
# 0                     PHONE        Unspecified     BROOKLYN           NaN
# 1                     PHONE        Unspecified     BROOKLYN           NaN
# 2                    ONLINE        Unspecified    MANHATTAN           NaN
# 3                   UNKNOWN        Unspecified    MANHATTAN           NaN
# 4                    ONLINE        Unspecified    MANHATTAN           NaN
# ...                     ...                ...          ...           ...
# 3296                 ONLINE        Unspecified       QUEENS           NaN
# 3297                 ONLINE        Unspecified    MANHATTAN           NaN
# 3298                  PHONE        Unspecified    MANHATTAN           NaN
# 3299                 ONLINE        Unspecified    MANHATTAN           NaN
# 3300                  PHONE        Unspecified    MANHATTAN           NaN
#
#       Taxi Company Borough                      Taxi Pick Up Location  \
# 0                      NaN                         La Guardia Airport
# 1                      NaN                      Grand Central Station
# 2                      NaN                                      Other
# 3                      NaN  WEST 32 STREET ANDWEST 33 STREETMANHATTAN
# 4                      NaN               5 UNIVERSITY PLACE MANHATTAN
# ...                    ...                                        ...
# 3296                   NaN                                      Other
# 3297                   NaN                                      Other
# 3298                   NaN                                      Other
# 3299                   NaN                                      Other
# 3300                   NaN                               Intersection
#
#       Bridge Highway Name  Bridge Highway Direction  Road Ramp  \
# 0                     NaN                       NaN        NaN
# 1                     NaN                       NaN        NaN
# 2                     NaN                       NaN        NaN
# 3                     NaN                       NaN        NaN
# 4                     NaN                       NaN        NaN
# ...                   ...                       ...        ...
# 3296                  NaN                       NaN        NaN
# 3297                  NaN                       NaN        NaN
# 3298                  NaN                       NaN        NaN
# 3299                  NaN                       NaN        NaN
# 3300                  NaN                       NaN        NaN
#
#       Bridge Highway Segment  Latitude  Longitude  \
# 0                        NaN        41        -74
# 1                        NaN        41        -74
# 2                        NaN        41        -74
# 3                        NaN        41        -74
# 4                        NaN        41        -74
# ...                      ...       ...        ...
# 3296                     NaN        41        -74
# 3297                     NaN        41        -74
# 3298                     NaN        41        -74
# 3299                     NaN        41        -74
# 3300                     NaN        41        -74
#
#                                       Location
# 0      (40.71466527154591, -73.94010889799512)
# 1      (40.68281699836376, -73.97554013353896)
# 2      (40.75319949386173, -73.96973213960263)
# 3       (40.75006595421169, -73.9921067617765)
# 4      (40.73092423524819, -73.99536355851659)
# ...                                        ...
# 3296    (40.77540484997966, -73.9082598804459)
# 3297  (40.714528821024324, -74.01567705701206)
# 3298  (40.738044161412894, -73.99633736110466)
# 3299   (40.73191238974752, -73.99658666250231)
# 3300   (40.72841273385018, -73.99425247243117)
#
# [3301 rows x 41 columns]

# %% [markdown]
# # Getting all 311 data
#
# Source: https://data.cityofnewyork.us/Social-Services/311-Service-Requests-from-2010-to-Present/erm2-nwe9/data
#
# Get via API

# %%
# df_311= pd.read_json('https://data.cityofnewyork.us/resource/erm2-nwe9.json')
# df_311

# %% [markdown]
# ### The below is as of Tuesday, March 21st 2023 at 3.48p.m.

# %%
# df_311.to_csv('df_311.csv')

# %% [markdown]
# # For whole 311 dataset

# %%
# df_whole_311=pd.read_csv('311_21032023.csv')
# df_whole_311

# %% [markdown]
# # Get Library Data

# %% [markdown]
# #### Starting with Queens
#
# Source: https://data.cityofnewyork.us/Education/Queens-Library-Branches/kh3d-xhq7

# %%
# df_queens_json = pd.read_json('https://data.cityofnewyork.us/resource/kh3d-xhq7.json')
# df_queens_json

# %% [markdown]
# # Brooklyn Library

# %%
df_brooklyn_lib = pd.read_csv('BPL_Locations.csv')
df_brooklyn_lib.head(5)
# Out:
#                    branch                                            address  \
# 0       Arlington Library  203 Arlington Ave. at Warwick St. Brooklyn, NY...
# 1       Bay Ridge Library    7223 Ridge Blvd. at 73rd St. Brooklyn, NY 11209
# 2         Bedford Library             496 Franklin Avenue Brooklyn, NY 11238
# 3    Borough Park Library      1265 43rd St. at 13th Ave. Brooklyn, NY 11219
# 4  Brighton Beach Library  16 Brighton First Rd. at Brighton Beach Ave. B...
#
#           phone                           position              bus subway  \
# 0  718.277.6105  40.680456600000, -73.887288700000          Q24;Q56      J
# 1  718.748.5709  40.633650700000, -74.029523500000    B4;B9;B64;B70      R
# 2  718.623.0012  40.681817000000, -73.956194800000  B25;B26;B48;B49    C;S
# 3  718.437.4085  40.638920000000, -73.989122700000      B11;B16;B35      D
# 4  718.946.2917  40.576178400000, -73.966799500000           B1;B68    B;Q
#
#                Monday             Tuesday           Wednesday  \
# 0  \n10:00am - 6:00pm  \n10:00am - 6:00pm   \n1:00pm - 8:00pm
# 1  \n10:00am - 6:00pm  \n10:00am - 6:00pm  \n10:00am - 8:00pm
# 2  \n10:00am - 6:00pm  \n10:00am - 6:00pm   \n1:00pm - 8:00pm
# 3  \n10:00am - 6:00pm  \n10:00am - 8:00pm  \n10:00am - 6:00pm
# 4  \n10:00am - 6:00pm   \n1:00pm - 8:00pm  \n10:00am - 8:00pm
#
#              Thursday              Friday            Saturday  \
# 0  \n10:00am - 8:00pm  \n10:00am - 6:00pm  \n10:00am - 5:00pm
# 1   \n1:00pm - 8:00pm  \n10:00am - 6:00pm  \n10:00am - 5:00pm
# 2  \n10:00am - 8:00pm  \n10:00am - 6:00pm  \n10:00am - 5:00pm
# 3  \n10:00am - 8:00pm  \n10:00am - 6:00pm                 NaN
# 4  \n10:00am - 6:00pm  \n10:00am - 6:00pm  \n10:00am - 5:00pm
#
#               Sunday            access  \
# 0                NaN  Fully accessible
# 1                NaN  Fully accessible
# 2                NaN  Fully accessible
# 3  \n1:00pm - 5:00pm  Fully accessible
# 4                NaN  Fully accessible
#
#                                          tags  \
# 0                        accessible;open now;
# 1                        accessible;open now;
# 2        accessible;open now;learning center;
# 3  accessible;open now;book drop;open sundays
# 4                        accessible;open now;
#
#                                                 path
# 0   https://www.bklynlibrary.org/locations/arlington
# 1   https://www.bklynlibrary.org/locations/bay-ridge
# 2     https://www.bklynlibrary.org/locations/bedford
# 3  https://www.bklynlibrary.org/locations/borough...
# 4  https://www.bklynlibrary.org/locations/brighto...

# %%
# df_bklyn_electronic = pd.read_json('https://www.bklynlibrary.org/learning-resources/json')
# df_bklyn_electronic

# %% [markdown]
# #### Brooklyn Library electronic resources
#
# ##### In case helpful

# %%
# bklyn_elec_url='https://data.cityofnewyork.us/resource/ji82-xba5.json'
# bklyn_elec_raw_html = requests.get(bklyn_elec_url).content
    
# # soup_doc = BeautifulSoup(raw_html, "html.parser")

# %% [markdown]
# # bklyn_elec_raw_html
# This has a b' in the intro and \n at the end that I need to figure out but since I doubt I will use it I am putting it off for now

# %% [markdown]
# # Facilities

# %%
# df_facilities_json = pd.read_json('https://data.cityofnewyork.us/resource/ji82-xba5.json')
# df_facilities_json

# %%
# df_whole_311['descriptor'].value_counts()

# %% [markdown]
# # Banned books in the world

# %% [markdown]
# Source of banned books in the world: https://en.wikipedia.org/wiki/List_of_books_banned_by_governments <br/>
# Source of books in the world: World Digital Library <br/>
# Source of banned books by decade: https://www.ala.org/advocacy/bbooks/frequentlychallengedbooks/top100 <br/>
# Source of censorship attacks: https://www.everylibraryinstitute.org/book_censorship_database_magnusson <br/>
# Source of censored books in India: https://en.wikipedia.org/wiki/List_of_books_banned_in_India
# Other online searches for publication dates

# %%
#read csvs and excel files

df_digital_books=pd.read_csv('wdl_data_en.csv')

df_digital_books
# Out:
#        wdl_id                                              title  \
# 0           1  Antietam, Maryland. Allan Pinkerton, President...
# 1           2  Chola Woman, Full-Length Portrait, Standing, F...
# 2           3           Maps of Ezo, Sakhalin, and Kuril Islands
# 3           4                          Warrior Asahina Kobayashi
# 4           5     Manuscript Map of Dagua River Region, Colombia
# ...       ...                                                ...
# 19142   28001                                      Village Court
# 19143   28002                               Children's Formation
# 19144   28003           Government of the Village of Novorybinsk
# 19145   28004                                 Village Bread Shop
# 19146   28005           Government of the Village of Medvezhensk
#
#                                           collection  \
# 0                                                NaN
# 1             Frank and Frances Carpenter Collection
# 2                                                NaN
# 3            Japanese Prints and Drawings Collection
# 4                                                NaN
# ...                                              ...
# 19142  Types of Buildings in the Cossack Settlements
# 19143  Types of Buildings in the Cossack Settlements
# 19144  Types of Buildings in the Cossack Settlements
# 19145  Types of Buildings in the Cossack Settlements
# 19146  Types of Buildings in the Cossack Settlements
#
#                                              description  \
# 0      At the outset of the U.S. Civil War, Mathew Br...
# 1      This photograph of a Bolivian woman is from th...
# 2      This map was made by Fujita Junsai and publish...
# 3      The Japanese art of Ukiyo-e (“Pictures of the ...
# 4      This beautiful pen-and-ink and watercolor map ...
# ...                                                  ...
# 19142  This image is from Tipy postroek v stanitsakh ...
# 19143  This image is from Tipy postroek v stanitsakh ...
# 19144  This image is from Tipy postroek v stanitsakh ...
# 19145  This image is from Tipy postroek v stanitsakh ...
# 19146  This image is from Tipy postroek v stanitsakh ...
#
#                               title_in_original_language  \
# 0      Antietam, Maryland. Allan Pinkerton, President...
# 1                                                    NaN
# 2                                               蝦夷闔境輿地全図
# 3                                   Kobayashi no Asahina
# 4                                                    NaN
# ...                                                  ...
# 19142                                      Станичный суд
# 19143                                      Детский строй
# 19144                  Новорыбинское станичное правление
# 19145                    Станичный хлебозапасный магазин
# 19146                   Медвеженское станичное правление
#
#                                  wdl_url  \
# 0          https://www.wdl.org/en/item/1
# 1          https://www.wdl.org/en/item/2
# 2          https://www.wdl.org/en/item/3
# 3          https://www.wdl.org/en/item/4
# 4          https://www.wdl.org/en/item/5
# ...                                  ...
# 19142  https://www.wdl.org/en/item/28001
# 19143  https://www.wdl.org/en/item/28002
# 19144  https://www.wdl.org/en/item/28003
# 19145  https://www.wdl.org/en/item/28004
# 19146  https://www.wdl.org/en/item/28005
#
#                                       handle         Type of Item  \
# 0          https://hdl.loc.gov/loc.wdl/wdl.1  Prints, Photographs
# 1          https://hdl.loc.gov/loc.wdl/wdl.2  Prints, Photographs
# 2          https://hdl.loc.gov/loc.wdl/wdl.3                 Maps
# 3          https://hdl.loc.gov/loc.wdl/wdl.4  Prints, Photographs
# 4          https://hdl.loc.gov/loc.wdl/wdl.5                 Maps
# ...                                      ...                  ...
# 19142  https://hdl.loc.gov/loc.wdl/wdl.28001  Prints, Photographs
# 19143  https://hdl.loc.gov/loc.wdl/wdl.28002  Prints, Photographs
# 19144  https://hdl.loc.gov/loc.wdl/wdl.28003  Prints, Photographs
# 19145  https://hdl.loc.gov/loc.wdl/wdl.28004  Prints, Photographs
# 19146  https://hdl.loc.gov/loc.wdl/wdl.28005  Prints, Photographs
#
#                                              Institution  \
# 0                                    Library of Congress
# 1                                    Library of Congress
# 2                                    Library of Congress
# 3                                    Library of Congress
# 4                                    Library of Congress
# ...                                                  ...
# 19142  Omsk State Museum of Regional History and Folk...
# 19143  Omsk State Museum of Regional History and Folk...
# 19144  Omsk State Museum of Regional History and Folk...
# 19145  Omsk State Museum of Regional History and Folk...
# 19146  Omsk State Museum of Regional History and Folk...
#
#                         Photographer Date Created Subject Date  \
# 0      Gardner, Alexander, 1821-1882   1862-10-03   1862-10-03
# 1          Vargas, Max T., 1874–1959         1911    1900/1923
# 2                                NaN         1854         1854
# 3                                NaN         1862         1862
# 4                                NaN         1764         1764
# ...                              ...          ...          ...
# 19142                 Katanaev, N.G.    1909/1911    1909/1911
# 19143                 Katanaev, N.G.    1909/1911    1909/1911
# 19144                 Katanaev, N.G.    1909/1911    1909/1911
# 19145                 Katanaev, N.G.    1909/1911    1909/1911
# 19146                 Katanaev, N.G.    1909/1911    1909/1911
#
#                                                    Place Dewey Decimal Code  \
# 0      North America > United States of America > Mar...                973
# 1      Latin America and the Caribbean > Bolivia > La...                391
# 2      East Asia > Japan > Hokkaido|Europe > Russian ...                912
# 3                                      East Asia > Japan            769|792
# 4      Latin America and the Caribbean > Colombia > V...                912
# ...                                                  ...                ...
# 19142                Central and South Asia > Kazakhstan                947
# 19143                Central and South Asia > Kazakhstan                947
# 19144                Central and South Asia > Kazakhstan                947
# 19145                Central and South Asia > Kazakhstan                947
# 19146                Central and South Asia > Kazakhstan                947
#
#                                      Additional Subjects  \
# 0      Antietam, Battle of, Maryland, 1862|Generals|L...
# 1                             Portrait photographs|Women
# 2                                                    NaN
# 3      Actors|Costumes|Japanese drama|Portrait prints...
# 4                                                 Rivers
# ...                                                  ...
# 19142                      Cossacks|Meeting of Frontiers
# 19143                      Cossacks|Meeting of Frontiers
# 19144                      Cossacks|Meeting of Frontiers
# 19145                      Cossacks|Meeting of Frontiers
# 19146                      Cossacks|Meeting of Frontiers
#
#                                     Physical Description         Creator  \
# 0                      1 negative : glass, wet collodion             NaN
# 1                                                    NaN             NaN
# 2      1 color map, 115 x 92 centimeters, folded in c...  Fujita, Tonsai
# 3      1 print: woodcut, color ; 29.0 x 21.3 centimeters             NaN
# 4         1 manuscript map : color ; 60 x 86 centimeters             NaN
# ...                                                  ...             ...
# 19142                                       1 photograph             NaN
# 19143                                       1 photograph             NaN
# 19144                                       1 photograph             NaN
# 19145                                       1 photograph             NaN
# 19146                                       1 photograph             NaN
#
#                 Publisher Place of Publication  Language  \
# 0                     NaN                  NaN       NaN
# 1                     NaN                  NaN       NaN
# 2      Harimaya Katsugorō                  Edo  Japanese
# 3                     NaN                  NaN  Japanese
# 4                     NaN                  NaN   Spanish
# ...                   ...                  ...       ...
# 19142                 NaN                  NaN   Russian
# 19143                 NaN                  NaN   Russian
# 19144                 NaN                  NaN   Russian
# 19145                 NaN                  NaN   Russian
# 19146                 NaN                  NaN   Russian
#
#                              Artist Cartographer Note Delineator Author  \
# 0                               NaN          NaN  NaN        NaN    NaN
# 1                               NaN          NaN  NaN        NaN    NaN
# 2                               NaN          NaN  NaN        NaN    NaN
# 3      Utagawa, Toyokuni, 1786-1865          NaN  NaN        NaN    NaN
# 4                               NaN          NaN  NaN        NaN    NaN
# ...                             ...          ...  ...        ...    ...
# 19142                           NaN          NaN  NaN        NaN    NaN
# 19143                           NaN          NaN  NaN        NaN    NaN
# 19144                           NaN          NaN  NaN        NaN    NaN
# 19145                           NaN          NaN  NaN        NaN    NaN
# 19146                           NaN          NaN  NaN        NaN    NaN
#
#       Surveyor Compiler Translator Contributor Engraver Cinematographer  \
# 0          NaN      NaN        NaN         NaN      NaN             NaN
# 1          NaN      NaN        NaN         NaN      NaN             NaN
# 2          NaN      NaN        NaN         NaN      NaN             NaN
# 3          NaN      NaN        NaN         NaN      NaN             NaN
# 4          NaN      NaN        NaN         NaN      NaN             NaN
# ...        ...      ...        ...         ...      ...             ...
# 19142      NaN      NaN        NaN         NaN      NaN             NaN
# 19143      NaN      NaN        NaN         NaN      NaN             NaN
# 19144      NaN      NaN        NaN         NaN      NaN             NaN
# 19145      NaN      NaN        NaN         NaN      NaN             NaN
# 19146      NaN      NaN        NaN         NaN      NaN             NaN
#
#       Director Illustrator Sponsor Draftsman Editor Corrector  \
# 0          NaN         NaN     NaN       NaN    NaN       NaN
# 1          NaN         NaN     NaN       NaN    NaN       NaN
# 2          NaN         NaN     NaN       NaN    NaN       NaN
# 3          NaN         NaN     NaN       NaN    NaN       NaN
# 4          NaN         NaN     NaN       NaN    NaN       NaN
# ...        ...         ...     ...       ...    ...       ...
# 19142      NaN         NaN     NaN       NaN    NaN       NaN
# 19143      NaN         NaN     NaN       NaN    NaN       NaN
# 19144      NaN         NaN     NaN       NaN    NaN       NaN
# 19145      NaN         NaN     NaN       NaN    NaN       NaN
# 19146      NaN         NaN     NaN       NaN    NaN       NaN
#
#       Responsible Party Calligrapher Interviewee Interviewer Associated Name  \
# 0                   NaN          NaN         NaN         NaN             NaN
# 1                   NaN          NaN         NaN         NaN             NaN
# 2                   NaN          NaN         NaN         NaN             NaN
# 3                   NaN          NaN         NaN         NaN             NaN
# 4                   NaN          NaN         NaN         NaN             NaN
# ...                 ...          ...         ...         ...             ...
# 19142               NaN          NaN         NaN         NaN             NaN
# 19143               NaN          NaN         NaN         NaN             NaN
# 19144               NaN          NaN         NaN         NaN             NaN
# 19145               NaN          NaN         NaN         NaN             NaN
# 19146               NaN          NaN         NaN         NaN             NaN
#
#       Printer Lithographer Donor Recording Engineer Musician Composer  \
# 0         NaN          NaN   NaN                NaN      NaN      NaN
# 1         NaN          NaN   NaN                NaN      NaN      NaN
# 2         NaN          NaN   NaN                NaN      NaN      NaN
# 3         NaN          NaN   NaN                NaN      NaN      NaN
# 4         NaN          NaN   NaN                NaN      NaN      NaN
# ...       ...          ...   ...                ...      ...      ...
# 19142     NaN          NaN   NaN                NaN      NaN      NaN
# 19143     NaN          NaN   NaN                NaN      NaN      NaN
# 19144     NaN          NaN   NaN                NaN      NaN      NaN
# 19145     NaN          NaN   NaN                NaN      NaN      NaN
# 19146     NaN          NaN   NaN                NaN      NaN      NaN
#
#       Architect References Attributed Name Dedicatee Signer Copyright Holder  \
# 0           NaN        NaN             NaN       NaN    NaN              NaN
# 1           NaN        NaN             NaN       NaN    NaN              NaN
# 2           NaN        NaN             NaN       NaN    NaN              NaN
# 3           NaN        NaN             NaN       NaN    NaN              NaN
# 4           NaN        NaN             NaN       NaN    NaN              NaN
# ...         ...        ...             ...       ...    ...              ...
# 19142       NaN        NaN             NaN       NaN    NaN              NaN
# 19143       NaN        NaN             NaN       NaN    NaN              NaN
# 19144       NaN        NaN             NaN       NaN    NaN              NaN
# 19145       NaN        NaN             NaN       NaN    NaN              NaN
# 19146       NaN        NaN             NaN       NaN    NaN              NaN
#
#       Collector Printmaker Copyright claimant Performer Owner Commentator  \
# 0           NaN        NaN                NaN       NaN   NaN         NaN
# 1           NaN        NaN                NaN       NaN   NaN         NaN
# 2           NaN        NaN                NaN       NaN   NaN         NaN
# 3           NaN        NaN                NaN       NaN   NaN         NaN
# 4           NaN        NaN                NaN       NaN   NaN         NaN
# ...         ...        ...                ...       ...   ...         ...
# 19142       NaN        NaN                NaN       NaN   NaN         NaN
# 19143       NaN        NaN                NaN       NaN   NaN         NaN
# 19144       NaN        NaN                NaN       NaN   NaN         NaN
# 19145       NaN        NaN                NaN       NaN   NaN         NaN
# 19146       NaN        NaN                NaN       NaN   NaN         NaN
#
#       Etcher Wood-engraver Scribe Author of Introduction, etc.  \
# 0        NaN           NaN    NaN                          NaN
# 1        NaN           NaN    NaN                          NaN
# 2        NaN           NaN    NaN                          NaN
# 3        NaN           NaN    NaN                          NaN
# 4        NaN           NaN    NaN                          NaN
# ...      ...           ...    ...                          ...
# 19142    NaN           NaN    NaN                          NaN
# 19143    NaN           NaN    NaN                          NaN
# 19144    NaN           NaN    NaN                          NaN
# 19145    NaN           NaN    NaN                          NaN
# 19146    NaN           NaN    NaN                          NaN
#
#       Author of Afterword, Colophon, etc. Scientific advisor Speaker  \
# 0                                     NaN                NaN     NaN
# 1                                     NaN                NaN     NaN
# 2                                     NaN                NaN     NaN
# 3                                     NaN                NaN     NaN
# 4                                     NaN                NaN     NaN
# ...                                   ...                ...     ...
# 19142                                 NaN                NaN     NaN
# 19143                                 NaN                NaN     NaN
# 19144                                 NaN                NaN     NaN
# 19145                                 NaN                NaN     NaN
# 19146                                 NaN                NaN     NaN
#
#       Commentator for Written Text Illuminator Librettist Client Transcriber  \
# 0                              NaN         NaN        NaN    NaN         NaN
# 1                              NaN         NaN        NaN    NaN         NaN
# 2                              NaN         NaN        NaN    NaN         NaN
# 3                              NaN         NaN        NaN    NaN         NaN
# 4                              NaN         NaN        NaN    NaN         NaN
# ...                            ...         ...        ...    ...         ...
# 19142                          NaN         NaN        NaN    NaN         NaN
# 19143                          NaN         NaN        NaN    NaN         NaN
# 19144                          NaN         NaN        NaN    NaN         NaN
# 19145                          NaN         NaN        NaN    NaN         NaN
# 19146                          NaN         NaN        NaN    NaN         NaN
#
#       Collaborator Producer Videographer Vocalist Patron Funder Annotator  \
# 0              NaN      NaN          NaN      NaN    NaN    NaN       NaN
# 1              NaN      NaN          NaN      NaN    NaN    NaN       NaN
# 2              NaN      NaN          NaN      NaN    NaN    NaN       NaN
# 3              NaN      NaN          NaN      NaN    NaN    NaN       NaN
# 4              NaN      NaN          NaN      NaN    NaN    NaN       NaN
# ...            ...      ...          ...      ...    ...    ...       ...
# 19142          NaN      NaN          NaN      NaN    NaN    NaN       NaN
# 19143          NaN      NaN          NaN      NaN    NaN    NaN       NaN
# 19144          NaN      NaN          NaN      NaN    NaN    NaN       NaN
# 19145          NaN      NaN          NaN      NaN    NaN    NaN       NaN
# 19146          NaN      NaN          NaN      NaN    NaN    NaN       NaN
#
#       Woodcutter Designer Author in Quotations or Text Extracts Lyricist  \
# 0            NaN      NaN                                   NaN      NaN
# 1            NaN      NaN                                   NaN      NaN
# 2            NaN      NaN                                   NaN      NaN
# 3            NaN      NaN                                   NaN      NaN
# 4            NaN      NaN                                   NaN      NaN
# ...          ...      ...                                   ...      ...
# 19142        NaN      NaN                                   NaN      NaN
# 19143        NaN      NaN                                   NaN      NaN
# 19144        NaN      NaN                                   NaN      NaN
# 19145        NaN      NaN                                   NaN      NaN
# 19146        NaN      NaN                                   NaN      NaN
#
#       Type Designer Animator Writer of added text Project Director  \
# 0               NaN      NaN                  NaN              NaN
# 1               NaN      NaN                  NaN              NaN
# 2               NaN      NaN                  NaN              NaN
# 3               NaN      NaN                  NaN              NaN
# 4               NaN      NaN                  NaN              NaN
# ...             ...      ...                  ...              ...
# 19142           NaN      NaN                  NaN              NaN
# 19143           NaN      NaN                  NaN              NaN
# 19144           NaN      NaN                  NaN              NaN
# 19145           NaN      NaN                  NaN              NaN
# 19146           NaN      NaN                  NaN              NaN
#
#       Dubious Author Censor Engineer Lead Publishing Director Singer Binder  \
# 0                NaN    NaN      NaN  NaN                 NaN    NaN    NaN
# 1                NaN    NaN      NaN  NaN                 NaN    NaN    NaN
# 2                NaN    NaN      NaN  NaN                 NaN    NaN    NaN
# 3                NaN    NaN      NaN  NaN                 NaN    NaN    NaN
# 4                NaN    NaN      NaN  NaN                 NaN    NaN    NaN
# ...              ...    ...      ...  ...                 ...    ...    ...
# 19142            NaN    NaN      NaN  NaN                 NaN    NaN    NaN
# 19143            NaN    NaN      NaN  NaN                 NaN    NaN    NaN
# 19144            NaN    NaN      NaN  NaN                 NaN    NaN    NaN
# 19145            NaN    NaN      NaN  NaN                 NaN    NaN    NaN
# 19146            NaN    NaN      NaN  NaN                 NaN    NaN    NaN
#
#       Originator Typographer Book producer Narrator Colorist Arranger  \
# 0            NaN         NaN           NaN      NaN      NaN      NaN
# 1            NaN         NaN           NaN      NaN      NaN      NaN
# 2            NaN         NaN           NaN      NaN      NaN      NaN
# 3            NaN         NaN           NaN      NaN      NaN      NaN
# 4            NaN         NaN           NaN      NaN      NaN      NaN
# ...          ...         ...           ...      ...      ...      ...
# 19142        NaN         NaN           NaN      NaN      NaN      NaN
# 19143        NaN         NaN           NaN      NaN      NaN      NaN
# 19144        NaN         NaN           NaN      NaN      NaN      NaN
# 19145        NaN         NaN           NaN      NaN      NaN      NaN
# 19146        NaN         NaN           NaN      NaN      NaN      NaN
#
#       Recipient Correspondent
# 0           NaN           NaN
# 1           NaN           NaN
# 2           NaN           NaN
# 3           NaN           NaN
# 4           NaN           NaN
# ...         ...           ...
# 19142       NaN           NaN
# 19143       NaN           NaN
# 19144       NaN           NaN
# 19145       NaN           NaN
# 19146       NaN           NaN
#
# [19147 rows x 102 columns]

# %%
xl_book_censorship_attacks=pd.ExcelFile('book_censorship_attacks.xlsx')
xl_book_censorship_attacks.sheet_names
# Out:
# ['Books Challenged Schools 21-22',
#  'Books Challenge 22-23',
#  'New Groups',
#  'By School District 21-22',
#  'Books Challenged Schools 2020-2',
#  'Groups Formed In Response To Th',
#  'Books Challenged Public Librari',
#  'By Public LIbraries',
#  'Other Relevant Articles',
#  'Books Targeted By Groups',
#  'Groups Formed To Ban Books',
#  'KEY',
#  'Rep Krause 850 Texas Book List',
#  'Krause List By Author',
#  'NorthEastISD Texas']

# %%
df_challenged_2122 = pd.read_excel('book_censorship_attacks.xlsx', sheet_name='Books Challenged Schools 21-22')
df_challenged_2223 = pd.read_excel('book_censorship_attacks.xlsx', sheet_name='Books Challenge 22-23')
df_new_groups = pd.read_excel('book_censorship_attacks.xlsx', sheet_name='New Groups')
df_school_district_2122 = pd.read_excel('book_censorship_attacks.xlsx', sheet_name='By School District 21-22')
df_school_district_2021 = pd.read_excel('book_censorship_attacks.xlsx', sheet_name='Books Challenged Schools 2020-2')
df_challenging_groups = pd.read_excel('book_censorship_attacks.xlsx', sheet_name='Groups Formed In Response To Th')
df_challenged_public_libs = pd.read_excel('book_censorship_attacks.xlsx', sheet_name='Books Challenged Public Librari')
df_by_public_libs = pd.read_excel('book_censorship_attacks.xlsx', sheet_name='By Public LIbraries')
df_relevant_articles = pd.read_excel('book_censorship_attacks.xlsx', sheet_name='Other Relevant Articles')
df_targeted_by_groups = pd.read_excel('book_censorship_attacks.xlsx', sheet_name='Books Targeted By Groups')
df_groups_to_ban_books = pd.read_excel('book_censorship_attacks.xlsx', sheet_name='Groups Formed To Ban Books')
df_key = pd.read_excel('book_censorship_attacks.xlsx', sheet_name='KEY')
df_krause_texas_books = pd.read_excel('book_censorship_attacks.xlsx', sheet_name='Rep Krause 850 Texas Book List')
df_krause_texas_author = pd.read_excel('book_censorship_attacks.xlsx', sheet_name='Krause List By Author')
df_northeastISD = pd.read_excel('book_censorship_attacks.xlsx', sheet_name='NorthEastISD Texas')

# %% [markdown]
# ## Exploring number of books banned in the two most recent years

# %%
df_challenged_2223.shape
# Out:
# (2131, 43)

# %%
df_challenged_2122.shape
# Out:
# (4023, 16)

# %%
df_number_of_books_recent=pd.read_csv('number_of_books_challenged.csv')
df_number_of_books_recent
# Out:
#         Year  number_of_books_banned_or_challenged
# 0  2021-2022                                  2131
# 1  2022-2023                                  4023

# %% [markdown]
# ### Here is the resulting chart:
# https://www.datawrapper.de/_/Ppfvq/

# %% [markdown]
# # Starting exploration of banned books by country
# Source: https://en.wikipedia.org/wiki/List_of_books_banned_by_governments

# %%
df_banned_books_by_country=pd.read_csv('banned_books_by_country.csv')
df_banned_books_by_country
# Out:
#                                                  Title  \
# 0                     Përbindëshi (The Monster) (1965)
# 1                                        Lolita (1955)
# 2                                        The Decameron
# 3                         The 120 Days of Sodom (1789)
# 4                                        Droll Stories
# ..                                                 ...
# 390       Islam: A Concept of Political World Invasion
# 391             Jinnah: India, Partition, Independence
# 392  Great Soul: Mahatma Gandhi and His Struggle Wi...
# 393  Meendezhum Pandiyar Varalaru (Resurgence of Pa...
# 394                         The Adivasi Will Not Dance
#
#                     Author(s) year_published end_date end_date_r Year Banned  \
# 0               Ismail Kadare           1965     1990       1966         NaN
# 1            Vladimir Nabokov           1955     1955       1956         NaN
# 2          Giovanni Boccaccio           1353     1353       1354        1927
# 3             Marquis de Sade           1789     1789       1790        1957
# 4            Honoré de Balzac           1837     1837       1838  1901, 1928
# ..                        ...            ...      ...        ...         ...
# 390              R. V. Bhasin           2007     2007       2008         NaN
# 391             Jaswant Singh           2009     2009       2010         NaN
# 392           Joseph Lelyveld           2011     2011       2012         NaN
# 393         K. Senthil Mallar           2013     2013       2014         NaN
# 394  Hansda Sowvendra Shekhar           2017     2017       2018         NaN
#
#     Year Unbanned              Type  \
# 0             NaN             Novel
# 1             NaN             Novel
# 2            1936  Story collection
# 3       *Unknown*             Novel
# 4      1923, 1973     Short stories
# ..            ...               ...
# 390           NaN               NaN
# 391           NaN               NaN
# 392           NaN               NaN
# 393           NaN               NaN
# 394           NaN               NaN
#
#                                                  Notes    Country  \
# 0                   Banned for 25 years in Albania.[3]    Albania
# 1                       Banned for being "obscene".[4]  Argentina
# 2    Banned in Australia from 1927 to 1936 and from...  Australia
# 3    Banned by the Australian Government in 1957 fo...  Australia
# 4    Banned for obscenity from 1901 to 1923 and 192...  Australia
# ..                                                 ...        ...
# 390  The book was released in 2003. It was banned b...      India
# 391  Banned in Gujarat but overturned.[22] The book...      India
# 392  The biographical book suggested that Gandhi wa...      India
# 393  The Tamil Nadu government banned this Tamil bo...      India
# 394  On 11 August 2017, the government of Jharkhand...      India
#
#     nation_or_state        state
# 0               NaN          NaN
# 1               NaN          NaN
# 2               NaN          NaN
# 3               NaN          NaN
# 4               NaN          NaN
# ..              ...          ...
# 390       statewide  Maharashtra
# 391       statewide      Gujarat
# 392       statewide      Gujarat
# 393       statewide   Tamil Nadu
# 394       statewide    Jharkhand
#
# [395 rows x 12 columns]

# %% [markdown]
# # Exploring the most banned book titles by countries

# %%
df_banned_books_by_country.Title.value_counts().head(10)
# Out:
# The Satanic Verses (1988)         15
# Works                             11
# Mein Kampf (1925)                  5
# Lolita (1955)                      5
# Animal Farm                        3
# Droll Stories                      3
# Lady Chatterley's Lover (1928)     3
# Borstal Boy                        3
# The Anarchist Cookbook             2
# Satyarth Prakash                   2
# Name: Title, dtype: int64

# %% [markdown]
# #### Rushdie's The Satanic Verses has been banned three times as much as the second most banned book globally
# Resulting chart: https://public.flourish.studio/visualisation/13196372/

# %% [markdown]
# # Exploring the countries banning books most often

# %%
df_banned_books_by_country.Country.value_counts().head(10)
# Out:
# India             60
# China             34
# Singapore         32
# Ireland           24
# Australia         20
# United States     20
# Spain             16
# Germany           16
# Russia            15
# United Kingdom    14
# Name: Country, dtype: int64

# %%
df_country_count=df_banned_books_by_country.Country.value_counts()
df_country_count.to_csv('df_country_count.csv')

# %% [markdown]
# #### India has the most banned specific individual book titles but Indonesia has banned all Chinese literature in bulk
# Resulting chart: https://app.datawrapper.de/map/z6p8P/publish

# %% [markdown]
# # Exploring the types of books banned the most

# %%
df_type_count=df_banned_books_by_country.Type.value_counts()
df_type_count.to_csv('df_type_count.csv')

# %% [markdown]
# #### Nearly double the number of novels are banned compared to non-fiction books, including 67% of the 6 most banned books
# Resulting chart: https://app.flourish.studio/visualisation/13197121/edit

# %% [markdown]
# # Reading the banned books file in R

# %%
# %%R
#
# df_banned_books_by_country_r<-read_csv('banned_books_by_country.csv')
# Out:
# Rows: 395 Columns: 12
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (12): Title, Author(s), year_published, end_date, end_date_r, Year Banne...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# # Developing a plot to see the trends in banning across the years

# %% [markdown]
# ### Dot plot

# %%
# %%R -h 300 -w 900
#
# # Paste code below:
#
# ggplot(df_banned_books_by_country_r) +
#     aes(x=year_published, y=1, alpha=.05) +
#     geom_point() +
#     geom_vline(aes(xintercept=0), color='red')  +
#     labs(
#         title='Plotting the books by year',
# #         subtitle="positive numbers = polls overestimated DEM support\nnegative numbers= polls overestimated GOP support"
#     ) +
#     theme(legend.position="none")

# %% [markdown]
# #### Range of years exists
# However, there is a lot of overlap, perhaps jitter plot will help

# %% [markdown]
# ## Jitter plot

# %%
# %%R -h 900 -w 900
#
# # Paste code below:
#
# ggplot(df_banned_books_by_country_r) +
#     aes(x=year_published, y=1, alpha=.05, color=Type) +
#     geom_jitter() +
#     labs(
#         title='Plotting the books by year published',
# #         subtitle="positive numbers = polls overestimated DEM support\nnegative numbers= polls overestimated GOP support"
#     ) +
#     theme(legend.position="none")+
#     theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1))+
#     theme(panel.grid.major = element_blank(), panel.grid.minor = element_blank())

# %% [markdown]
# # How can this visualisation of timelines be reader facing?

# %% [markdown]
# ### Exploring how other people have made timelines

# %%
# %%R

# library(timevis)

# data_timeline <- df_banned_books_by_country_r.frame(
#   id      = df_banned_books_by_country_r$Title,
#   content = df_banned_books_by_country_r$Title,
#   start   = df_banned_books_by_country_r$year_published,
#   end     = df_banned_books_by_country_r$year_published
# )

# timevis(data_timeline)

# %% [markdown]
# #### How one person did it

# %%
# %%R
# library(vistime)
# library(shiny)
# library(plotly)
#
#
#
# data <- read.csv(text="event,start,end
#                        Phase 1,2020-12-15,2020-12-24
#                        Phase 2,2020-12-23,2020-12-29
#                        Phase 3,2020-12-28,2021-01-06
#                        Phase 4,2021-01-06,2021-02-02")
#
# gg_vistime(data, optimize_y = TRUE, linewidth = 25)

# %% [markdown]
# #### How another person did it

# %%
# %%R
#
# device.data <- data.frame(
#     DeviceName = c("Cypher Sirolimus DES", "Taxus Express 2", "Cypher Select Sirolimus DES",
#               "Cypher Select Plus Sirolimus DES", "Taxus Liberte", "Endeavor ABT578",
#               "Endeavor Sprint Zotarolimus DES", "Xience V", "Taxus Element Monrail ION",
#               "Xience Nano", "Promus Element Plus", "Xience Prime",
#              "Endeavor Resolute DES","Endeavor Resolute Integrity DES", "Promus Premier", "Xience Xpedition LL and SV"),
#     DeviceManufacturer = c("Cordis Cashel","Boston Scientific","Cordis Cashel",
#                      "Cordis Cashel","Boston Scientific","Medtronic Inc",
#                      "Medtronic Inc", "Abbott Vascular", "Boston Scientific",
#                      "Abbott Vascular","Boston Scientific", "Abbott Vascular",
#                      "Medtronic Inc", "Medtronic Inc","Boston Scientific", "Abbott Vascular"),
#     start_date = as.Date(c("2002-11-15", "2003-09-09", "2005-10-21",
#                      "2006-10-25","2008-02-05", "2008-02-27",
#                      "2009-06-10", "2009-08-21", "2011-08-19",
#                      "2011-10-24", "2012-01-30", "2012-04-10",
#                      "2012-04-14", "2013-03-07", "2013-09-30", "2014-02-19")),
#     end_date = as.Date(c("2007-07-18", "2010-11-10", "2007-07-18",
#                    "2013-04-05", "2013-11-01", "2016-03-31",
#                    "2016-03-31", "2016-03-31", "2011-09-16",
#                    "2016-03-31", "2016-03-31", "2016-03-31",
#                    "2016-03-31", "2016-03-31", "2016-03-31", "2016-03-31")),
#     stringsAsFactors = FALSE
#     )
# #data visualization
# vistime(device.data, events = "DeviceName", groups = "DeviceManufacturer",
#                      start = "start_date", end = "end_date")

# %% [markdown]
# ## Attempt at replicating

# %%
# %%R
#
#
# device.data <- df_banned_books_by_country_r.frame(
#     Title = as.list(df_banned_books_by_country_r$Title),
#     Year = as.list(df_banned_books_by_country_r$year_published),
#     start_date = as.Date(as.list(df_banned_books_by_country_r$year_published)),
#     end_date = as.Date(as.list(df_banned_books_by_country_r$end_date_r)),
#     stringsAsFactors = FALSE
#     )
# #data visualization
# vistime(device.data, events = "Title", groups = "Year",
#                      start = "start_date", end = "end_date")
# Out:
# R[write to console]: Error in df_banned_books_by_country_r.frame(Title = as.list(df_banned_books_by_country_r$Title),  :
#   could not find function "df_banned_books_by_country_r.frame"
# Error in df_banned_books_by_country_r.frame(Title = as.list(df_banned_books_by_country_r$Title),  :
#   could not find function "df_banned_books_by_country_r.frame"
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:331, in RMagics.eval(self, code)
#     329 try:
#     330     # Need the newline in case the last line in code is a comment.
# --> 331     value, visible = ro.r("withVisible({%s\n})" % code)
#     332 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     333     # Otherwise next return seems to have copy of error.
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/rpy2/robjects/__init__.py:459, in R.__call__(self, string)
#     458 p = rinterface.parse(string)
# --> 459 res = self.eval(p)
#     460 return conversion.get_conversion().rpy2py(res)
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/rpy2/robjects/functions.py:204, in SignatureTranslatedFunction.__call__(self, *args, **kwargs)
#     203         kwargs[r_k] = v
# --> 204 return (super(SignatureTranslatedFunction, self)
#     205         .__call__(*args, **kwargs))
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/rpy2/robjects/functions.py:127, in Function.__call__(self, *args, **kwargs)
#     126         new_kwargs[k] = cv.py2rpy(v)
# --> 127 res = super(Function, self).__call__(*new_args, **new_kwargs)
#     128 res = cv.rpy2py(res)
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/rpy2/rinterface_lib/conversion.py:45, in _cdata_res_to_rinterface.<locals>._(*args, **kwargs)
#      44 def _(*args, **kwargs):
# ---> 45     cdata = function(*args, **kwargs)
#      46     # TODO: test cdata is of the expected CType
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/rpy2/rinterface.py:815, in SexpClosure.__call__(self, *args, **kwargs)
#     814     if error_occured[0]:
# --> 815         raise embedded.RRuntimeError(_rinterface._geterrmessage())
#     816 return res
#
# RRuntimeError: Error in df_banned_books_by_country_r.frame(Title = as.list(df_banned_books_by_country_r$Title),  :
#   could not find function "df_banned_books_by_country_r.frame"
#
#
# During handling of the above exception, another exception occurred:
#
# RInterpreterError                         Traceback (most recent call last)
# Cell In [45], line 1
# ----> 1 get_ipython().run_cell_magic('R', '', '\n\ndevice.data <- df_banned_books_by_country_r.frame(\n    Title = as.list(df_banned_books_by_country_r$Title),\n    Year = as.list(df_banned_books_by_country_r$year_published),\n    start_date = as.Date(as.list(df_banned_books_by_country_r$year_published)),\n    end_date = as.Date(as.list(df_banned_books_by_country_r$end_date_r)),\n    stringsAsFactors = FALSE\n    )\n#data visualization\nvistime(device.data, events = "Title", groups = "Year", \n                     start = "start_date", end = "end_date")\n')
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2417, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2415 with self.builtin_trap:
#    2416     args = (magic_arg_s, cell)
# -> 2417     result = fn(*args, **kwargs)
#    2418 return result
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:868, in RMagics.R(self, line, cell, local_ns)
#     866     if not e.stdout.endswith(e.err):
#     867         print(e.err)
# --> 868     raise e
#     869 finally:
#     870     if self.device in ['png', 'svg']:
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:848, in RMagics.R(self, line, cell, local_ns)
#     846         return_output = False
#     847 else:
# --> 848     text_result, result, visible = self.eval(code)
#     849     text_output += text_result
#     850     if visible:
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:335, in RMagics.eval(self, code)
#     332 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     333     # Otherwise next return seems to have copy of error.
#     334     warning_or_other_msg = self.flush()
# --> 335     raise RInterpreterError(code, str(exception),
#     336                             warning_or_other_msg)
#     337 text_output = self.flush()
#     338 return text_output, value, visible[0]
#
# RInterpreterError: Failed to parse and evaluate line '\n\ndevice.data <- df_banned_books_by_country_r.frame(\n    Title = as.list(df_banned_books_by_country_r$Title),\n    Year = as.list(df_banned_books_by_country_r$year_published),\n    start_date = as.Date(as.list(df_banned_books_by_country_r$year_published)),\n    end_date = as.Date(as.list(df_banned_books_by_country_r$end_date_r)),\n    stringsAsFactors = FALSE\n    )\n#data visualization\nvistime(device.data, events = "Title", groups = "Year", \n                     start = "start_date", end = "end_date")\n'.
# R error message: 'Error in df_banned_books_by_country_r.frame(Title = as.list(df_banned_books_by_country_r$Title),  : \n  could not find function "df_banned_books_by_country_r.frame"'

# %%
# %%R
#
# device.data <- df_banned_books_by_country_r.frame(
#     Title = c(df_banned_books_by_country_r$Title),
#     Year = c(df_banned_books_by_country_r$year_published),
#     start_date = as.Date(c(df_banned_books_by_country_r$year_published)),
#     end_date = as.Date(c(df_banned_books_by_country_r$year_published)),
#     stringsAsFactors = FALSE
#     )
# #data visualization
# vistime(device.data, events = "Title", groups = "Year",
#                      start = "start_date", end = "end_date")
